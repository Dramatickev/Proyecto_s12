# %%
import pandas as pd

# %%
#Abrimos el DataFrame correspondiente para trabajar con él
gd0 = pd.read_csv("C:\Users\cib3r\Desktop\SCHOOL\Proyecto Triple10\Sprint 12\Proyect12\Proyecto_s12\data\geo_data_0.csv") 
gd0.head()
# Out:
#   Cell In[3], line 2
#     gd0 = pd.read_csv("C:\Users\cib3r\Desktop\SCHOOL\Proyecto Triple10\Sprint 12\Proyect12\Proyecto_s12\data\geo_data_0.csv")
#                                                                                                                             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
