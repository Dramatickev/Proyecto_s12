# %%
import pandas as pd

# %%
#Cargamos los DataFrames con los que trabajaremos

datos_G0 = pd.read_csv("../data/geo_data_0.csv") 
datos_G1 = pd.read_csv("../data/geo_data_1.csv")
datos_G2 = pd.read_csv("../data/geo_data_2.csv")

#Comenzaremos a trabajar con datos_G0 
datos_G0.head()
# Out:
#       id        f0        f1        f2     product
# 0  txEyH  0.705745 -0.497823  1.221170  105.280062
# 1  2acmU  1.334711 -0.340164  4.365080   73.037750
# 2  409Wp  1.022732  0.151990  1.419926   85.265647
# 3  iJLyR -0.032172  0.139033  2.978566  168.620776
# 4  Xdl7t  1.988431  0.155413  4.751769  154.036647

# %%
#Observamos la información general, en busca de valores nulos, tipos de datos, etc.
datos_G0.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       100000 non-null  str
#  1   f0       100000 non-null  float64
#  2   f1       100000 non-null  float64
#  3   f2       100000 non-null  float64
#  4   product  100000 non-null  float64
# dtypes: float64(4), str(1)
# memory usage: 3.8 MB
